# %% [markdown]
# 2007년<br />
# https://www.acmicpc.net/problem/1924

# %%
import datetime

x, y = map(int, input().split())
print(datetime.date(2007, x, y).strftime('%A').upper()[:3])
# Out:
# 1 1
# MON
